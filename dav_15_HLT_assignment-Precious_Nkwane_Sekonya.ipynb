# %% [markdown]
# # Assessment

# %% [markdown]
# Given the following dataset, answer the questions that follow. The necessary libraries have been imported.

# %% [markdown]
# Libraries

# %%
import matplotlib.pyplot as plt
from numpy import arange
import scipy.stats as stats
import pandas as pd
import seaborn as sns
import random as rnd

# %%
# %matplotlib inline

# %% [markdown]
# The data

# %%
data = pd.read_csv('athletes.csv', sep=',')
# Out:
# /opt/conda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (27) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.head()
# Out:
#    athlete_id           name               region          team  \
# 0      2554.0      Pj Ablang           South West   Double Edge
# 1      3517.0  Derek Abdella                  NaN           NaN
# 2      4691.0            NaN                  NaN           NaN
# 3      5164.0    Abo Brandon  Southern California  LAX CrossFit
# 4      5286.0    Bryce Abbey                  NaN           NaN
#
#               affiliate gender   age  height  weight   fran  \
# 0  Double Edge CrossFit   Male  24.0    70.0   166.0    NaN
# 1                   NaN   Male  42.0    70.0   190.0    NaN
# 2                   NaN    NaN   NaN     NaN     NaN    NaN
# 3          LAX CrossFit   Male  40.0    67.0     NaN  211.0
# 4                   NaN   Male  32.0    65.0   149.0  206.0
#
#           ...          deadlift  backsq  pullups  \
# 0         ...             400.0   305.0      NaN
# 1         ...               NaN     NaN      NaN
# 2         ...               NaN     NaN      NaN
# 3         ...             375.0   325.0     25.0
# 4         ...               NaN   325.0     50.0
#
#                                                  eat  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3               I eat 1-3 full cheat meals per week|
# 4  I eat quality foods but don't measure the amount|
#
#                                                train  \
# 0  I workout mostly at a CrossFit Affiliate|I hav...
# 1  I have a coach who determines my programming|I...
# 2                                                NaN
# 3  I workout mostly at a CrossFit Affiliate|I hav...
# 4  I workout mostly at a CrossFit Affiliate|I inc...
#
#                                           background  \
# 0  I played youth or high school level sports|I r...
# 1        I played youth or high school level sports|
# 2                                                NaN
# 3        I played youth or high school level sports|
# 4                           I played college sports|
#
#                                           experience  \
# 0  I began CrossFit with a coach (e.g. at an affi...
# 1  I began CrossFit with a coach (e.g. at an affi...
# 2                                                NaN
# 3  I began CrossFit by trying it alone (without a...
# 4  I began CrossFit by trying it alone (without a...
#
#                                             schedule     howlong  \
# 0         I do multiple workouts in a day 2x a week|   4+ years|
# 1         I do multiple workouts in a day 2x a week|   4+ years|
# 2                                                NaN         NaN
# 3                 I usually only do 1 workout a day|   4+ years|
# 4  I usually only do 1 workout a day|I strictly s...  1-2 years|
#
#    retrieved_datetime
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
#
# [5 rows x 28 columns]

# %% [markdown]
# # Question 1

# %% [markdown]
# #### Study the data. What is the size of the dataset?

# %%
data.shape
# Out:
# (423006, 28)

# %% [markdown]
# Shape of the data is 423006, with 28 columns.

# %%
data.size
# Out:
# 11844168

# %% [markdown]
# Size of the data is 11844168.

# %% [markdown]
# # Question 1.1

# %% [markdown]
# #### Generate summary statistics of the data.

# %% [markdown]
# Descriptive information:

# %%
data.describe()
# Out:
#           athlete_id            age        height         weight  \
# count  423003.000000  331110.000000  1.598690e+05  229890.000000
# mean   292748.166538      32.516750  1.206217e+02     170.896137
# std    184969.660327       7.730671  2.097995e+04      58.379799
# min        82.000000      13.000000  0.000000e+00       1.000000
# 25%    135091.500000      27.000000  6.600000e+01     145.000000
# 50%    275839.000000      31.000000  6.900000e+01     170.000000
# 75%    473188.000000      37.000000  7.200000e+01     192.000000
# max    633083.000000     125.000000  8.388607e+06   20175.000000
#
#                fran         helen         grace      filthy50      fgonebad  \
# count  5.542600e+04  3.027900e+04  4.074500e+04  1.935900e+04  2.973800e+04
# mean   9.886691e+02  1.207950e+03  5.766025e+02  2.127863e+03  1.472252e+03
# std    7.200430e+04  6.824091e+04  4.891145e+04  6.055021e+04  9.762688e+04
# min    1.000000e+00  1.000000e+00 -6.000000e+01  1.000000e+00  0.000000e+00
# 25%    2.150000e+02  5.250000e+02  1.490000e+02  1.308000e+03  2.400000e+02
# 50%    2.900000e+02  5.950000e+02  1.930000e+02  1.550000e+03  2.940000e+02
# 75%    3.920000e+02  6.940000e+02  2.620000e+02  1.809000e+03  3.360000e+02
# max    8.388607e+06  8.388607e+06  8.388607e+06  8.388607e+06  8.388607e+06
#
#              run400         run5k         candj        snatch      deadlift  \
# count  2.224600e+04  3.609700e+04  1.044350e+05  9.728000e+04  1.153230e+05
# mean   5.241279e+02  3.411464e+03  2.709107e+02  2.424957e+02  6.970503e+02
# std    5.628804e+04  1.251980e+05  2.596882e+04  2.708942e+04  5.523235e+04
# min    1.000000e+00  1.000000e+00 -4.500000e+01  0.000000e+00 -5.000000e+02
# 25%    6.200000e+01  1.242000e+03  1.400000e+02  1.050000e+02  2.550000e+02
# 50%    7.100000e+01  1.380000e+03  1.950000e+02  1.450000e+02  3.450000e+02
# 75%    8.400000e+01  1.560000e+03  2.350000e+02  1.850000e+02  4.150000e+02
# max    8.388607e+06  8.388607e+06  8.388607e+06  8.388607e+06  8.388607e+06
#
#              backsq       pullups
# count  1.105170e+05  5.060800e+04
# mean   5.852109e+02  4.269613e+04
# std    5.052976e+04  9.546078e+06
# min   -7.000000e+00 -6.000000e+00
# 25%    2.050000e+02  1.500000e+01
# 50%    2.750000e+02  2.700000e+01
# 75%    3.350000e+02  3.900000e+01
# max    8.388607e+06  2.147484e+09

# %% [markdown]
# Data columns:

# %%
data.columns
# Out:
# Index(['athlete_id', 'name', 'region', 'team', 'affiliate', 'gender', 'age',
#        'height', 'weight', 'fran', 'helen', 'grace', 'filthy50', 'fgonebad',
#        'run400', 'run5k', 'candj', 'snatch', 'deadlift', 'backsq', 'pullups',
#        'eat', 'train', 'background', 'experience', 'schedule', 'howlong',
#        'retrieved_datetime'],
#       dtype='object')

# %% [markdown]
# # Question 1.2

# %% [markdown]
# Are the any missing values? A simple strategy would be to remove rows with missing values. This can however reduce the size of the dataset. Another technique is to imput missing values with a sensible value like the mean.
#
# For more on how to deal with missing values, see this blog entry: How to Handle Missing Data with Python. https://machinelearningmastery.com/handle-missing-data-python/

# %% [markdown]
# Count the missing values:

# %%
data.isnull().sum(axis=0) # count the missing values in each colum
# Out:
# athlete_id                 3
# name                   91896
# region                171744
# team                  267846
# affiliate             181090
# gender                 91896
# age                    91896
# height                263137
# weight                193116
# fran                  367580
# helen                 392727
# grace                 382261
# filthy50              403647
# fgonebad              393268
# run400                400760
# run5k                 386909
# candj                 318571
# snatch                325726
# deadlift              307683
# backsq                312489
# pullups               372398
# eat                   329074
# train                 317175
# background            324061
# experience            318070
# schedule              325131
# howlong               313800
# retrieved_datetime    114061
# dtype: int64

# %% [markdown]
# Drop all the missing values

# %%
data.dropna() # returns the dataset minus al
# Out:
#         athlete_id                name               region  \
# 34057     244917.0      Andrew Hanscom           South West
# 34127       7292.0           Nick Ryan            Australia
# 34153       2162.0       Matthew Swift            Australia
# 34154       7806.0         Ross Vivion           South West
# 34533     259585.0       Adam Trussell           North East
# 34651       7698.0     Stephen Pelcher           South East
# 34661      17086.0     Patrick Scheper         Mid Atlantic
# 34720       3549.0         Ed Whieldon               Europe
# 34825     121349.0  Sangote Ulupano Jr        South Central
# 34838     208358.0       Robbie Wilson        South Central
# 34894     137313.0       Austin Conner        South Central
# 35036       7492.0        Scott Todnem        North Central
# 35050     100252.0       Robert Gerdes        North Central
# 35073     246893.0      Andrew Haarsma            Australia
# 35125      29843.0       Michael Sovak           North East
# 35132      93557.0   Alexandre Campino  Southern California
# 35297      55514.0              Ed Siu         Mid Atlantic
# 35299      91497.0       Timothy Hines         Mid Atlantic
# 35301     102205.0      Donald Waldera           South East
# 35372     237488.0        Joshua McGee         Mid Atlantic
# 35457      76552.0        Adam Shipley         Central East
# 35466       6740.0       Pat Smulligan           North East
# 35554      95883.0       Eric Hambidge           North East
# 35556      96985.0         carl bryson               Europe
# 35565     122899.0      Cody Galbreath        North Central
# 35622      96457.0         Paul Caruso         Mid Atlantic
# 35649     112743.0     anthony barrett               Europe
# 35682       3864.0        Buckley Tole  Northern California
# 35807      12577.0         Tony Shelly        South Central
# 35839     250651.0         Max Mishkin        North Central
# ...            ...                 ...                  ...
# 223241     25167.0      Kristy Bracken           North West
# 227249    101484.0        Penny Turner            Australia
# 227647     12989.0       Mary Lunsford           South East
# 251087     19844.0       Valerie Foley           South West
# 262647    170657.0          Tony Boggs         Mid Atlantic
# 262860    148052.0           DJ Bonoan           South East
# 264438      2383.0          Matt Burns        North Central
# 266392     28499.0     Dennis Cheatham         Central East
# 275889    147563.0     Adam J Geraldes          Canada East
# 276507     15747.0  Maris Goldsborough  Northern California
# 277864    334717.0      Justin Hawkins           North West
# 280063      4017.0      Chris Kassulke            Australia
# 301042     50834.0     Marco Rodriguez         Central East
# 302110     23264.0         Peter Ryder            Australia
# 305858    104331.0           Web Smith         Central East
# 308199      1931.0         Tony Taddeo  Southern California
# 311104    214649.0         Bill Vastis          Canada East
# 324132      9973.0    Keegan Wolfenden            Australia
# 329555     12472.0        lindsey dion           North West
# 330125    103654.0        Christy Enos           South East
# 340994     14888.0      Megan Mitchell  Northern California
# 348791     15819.0      Lindsay Schuil  Southern California
# 352291      7196.0      Jaala Thibault  Southern California
# 355592     44486.0       Megan Kennedy         Mid Atlantic
# 362004     26444.0        Brian Curley           North East
# 372328     22627.0       Keith McGuire           South East
# 375133    103943.0       Robert Payton           South East
# 380392      4932.0        Troy Straith          Canada West
# 382760    110296.0      Dennis Walczyk           South West
# 421423    506969.0      Heather Garcia        North Central
#
#                                           team                  affiliate  \
# 34057                      CrossFit Cedar City        CrossFit Cedar City
# 34127                                Cfbb team         CrossFit Blackburn
# 34153                        CrossFit Brisbane          CrossFit Brisbane
# 34154                         Outcast CrossFit           Outcast CrossFit
# 34533                             CrossFit EXP               CrossFit EXP
# 34651                    Swamp Rabbit CrossFit      Swamp Rabbit CrossFit
# 34661                              21 CrossFit                21 CrossFit
# 34720                                  Team 3D         Reebok CrossFit 3D
# 34825                                  PRIME 1               CrossFit HEB
# 34838                    CrossFit Liberty Hill      CrossFit Liberty Hill
# 34894                      FitnessLab CrossFit        FitnessLab CrossFit
# 35036                         CrossFit Amplify           CrossFit Amplify
# 35050                     CrossFit South Metro       CrossFit South Metro
# 35073                                Team Mode              CrossFit Mode
# 35125                     CrossFit Westchester       CrossFit Westchester
# 35132                    CrossFit Perris Black            CrossFit Perris
# 35297                    CrossFit Federal Hill      CrossFit Federal Hill
# 35299                         CrossFit Go Hard           CrossFit Go Hard
# 35301                       CrossFit Perimeter         CrossFit Perimeter
# 35372                             CrossFit LIT               CrossFit LIT
# 35457   Thunder Valley CrossFit Dirty Snatches    Thunder Valley CrossFit
# 35466                       CrossFit Merrimack         CrossFit Merrimack
# 35554                               Team Inguz             CrossFit Inguz
# 35556                              Team Napalm            CrossFit Napalm
# 35565                             CrossFit 217               CrossFit 217
# 35622                    CrossFit Indian Trail      CrossFit Indian Trail
# 35649                          CrossFit Mallow            CrossFit Mallow
# 35682                     Morgan Hill Crossfit       Morgan Hill CrossFit
# 35807                          CrossFit Hville            CrossFit Hville
# 35839                           CrossFit Jenks             CrossFit Jenks
# ...                                        ...                        ...
# 223241                     Industrial Crossfit        Industrial CrossFit
# 227249                      CrossFit CrossAxed         CrossFit Crossaxed
# 227647                         CFNA Cockdiesel     CrossFit North Atlanta
# 251087                     CrossFit Initiative        CrossFit Initiative
# 262647                        Trident Crossfit           Trident CrossFit
# 262860                      Aero Firebreathers              CrossFit Aero
# 264438                             Woodbarians          CrossFit Woodbury
# 266392                              Team Talon             CrossFit Talon
# 275889                        CrossFit Streets           CrossFit Streets
# 276507                      CrossFit Brentwood         CrossFit Brentwood
# 277864                   Rogue Valley CrossFit      Rogue Valley CrossFit
# 280063                      CrossFit Toowoomba         CrossFit Toowoomba
# 301042                     Motor City CrossFit        Motor City CrossFit
# 302110                        CrossFit Dunedin           CrossFit Dunedin
# 305858                      CrossFit Grandview         CrossFit Grandview
# 308199                            CrossFit ATR               CrossFit ATR
# 311104                         CrossFit Cordis            CrossFit Cordis
# 324132                 Crossfit Lake Macquarie    CrossFit Lake Macquarie
# 329555              TheLAB - Eastlake CrossFit          CrossFit Eastlake
# 330125                           CrossFit Ybor              CrossFit Ybor
# 340994                     CrossFit Santa Cruz        CrossFit Santa Cruz
# 348791                     CrossFit Costa Mesa        CrossFit Costa Mesa
# 352291                       CrossFit Ventucky           CrossFit Ventura
# 355592            12 Labours CrossFit Columbia        12 Labours CrossFit
# 362004                            CFNE Courage       CrossFit New England
# 372328                       FireBase Infidels          CrossFit FireBase
# 375133                         Crossfit Ambush            CrossFit Ambush
# 380392                             CrossFit BC                CrossFit BC
# 382760               Colorado Springs Crossfit  CrossFit Colorado Springs
# 421423                           CrossFit COMO              CrossFit COMO
#
#         gender   age  height  weight    fran         ...           deadlift  \
# 34057     Male  25.0    70.0   183.0   189.0         ...              505.0
# 34127     Male  28.0    67.0   179.0   210.0         ...              540.0
# 352291  Female  35.0    65.0   133.0   288.0         ...              270.0
# 355592  Female  33.0    67.0   170.0   240.0         ...              305.0
# 362004    Male  54.0    73.0   196.0   201.0         ...              405.0
# 372328    Male  55.0    73.0   185.0   295.0         ...              335.0
# 375133    Male  56.0    66.0   171.0   447.0         ...              295.0
# 380392    Male  54.0    76.0   204.0   292.0         ...              345.0
# 382760    Male  36.0    72.0   225.0   198.0         ...              440.0
# 421423  Female  36.0    60.0   196.0   495.0         ...              235.0
#
#         backsq  pullups                                                eat  \
# 34057    400.0     54.0  I eat quality foods but don't measure the amount|
# 34127    357.0     80.0  I eat quality foods but don't measure the amount|
# 34153    419.0     40.0  I eat quality foods but don't measure the amount|
# 34154    400.0     52.0  I eat quality foods but don't measure the amount|
# 34533    355.0     20.0  I eat quality foods but don't measure the amount|
# 34651    355.0     42.0  I eat quality foods but don't measure the amount|
# 34661    400.0     37.0  I eat quality foods but don't measure the amou...
# 34720    287.0     30.0  I eat quality foods but don't measure the amou...
# 34825    420.0     43.0                      I eat whatever is convenient|
# 34838    410.0     42.0                      I eat whatever is convenient|
# 34894    365.0     29.0  I eat quality foods but don't measure the amou...
# 35036    385.0     54.0  I eat quality foods but don't measure the amount|
# 35050    484.0     50.0  I eat quality foods but don't measure the amount|
# 35073    359.0     32.0  I eat quality foods but don't measure the amount|
# 35125    365.0     45.0  I eat quality foods but don't measure the amount|
# 35132    306.0     40.0  I eat quality foods but don't measure the amount|
# 35297    315.0     45.0  I eat quality foods but don't measure the amount|
# 35299    260.0     23.0  I weigh and measure my food|I eat quality food...
# 35301    320.0     40.0  I eat quality foods but don't measure the amou...
# 35372    325.0     30.0  I eat quality foods but don't measure the amount|
# 35457    405.0     50.0  I eat quality foods but don't measure the amount|
# 35466    405.0     46.0  I eat quality foods but don't measure the amount|
# 35554    265.0     21.0  I eat quality foods but don't measure the amou...
# 35556    298.0     22.0  I eat strict Paleo|I eat quality foods but don...
# 35565    365.0     21.0  I eat quality foods but don't measure the amount|
# 35622    320.0     50.0                      I eat whatever is convenient|
# 35649    335.0     35.0  I eat quality foods but don't measure the amount|
# 35682    465.0     20.0  I weigh and measure my food|I eat quality food...
# 35807    365.0     41.0  I eat quality foods but don't measure the amou...
# 35839    455.0     21.0  I eat quality foods but don't measure the amount|
# ...        ...      ...                                                ...
# 223241   275.0     10.0  I eat quality foods but don't measure the amount|
# 227249   194.0     13.0  I eat quality foods but don't measure the amount|
# 227647   185.0     12.0  I eat strict Paleo|I eat quality foods but don...
# 251087   160.0      7.0   I eat strict Paleo|I eat whatever is convenient|
# 262647   405.0     51.0                      I eat whatever is convenient|
# 262860    50.0      1.0  I eat whatever is convenient|I eat 1-3 full ch...
# 264438   365.0     40.0  I eat quality foods but don't measure the amount|
# 266392   415.0     45.0  I eat strict Paleo|I eat quality foods but don...
# 275889   275.0     24.0  I weigh and measure my food|I eat 1-3 full che...
# 276507   305.0     12.0                      I eat whatever is convenient|
# 277864   180.0      8.0  I eat quality foods but don't measure the amount|
# 280063   265.0     20.0    I weigh and measure my food|I eat strict Paleo|
# 301042   255.0     34.0  I weigh and measure my food|I eat 1-3 full che...
# 302110   364.0     25.0  I eat quality foods but don't measure the amount|
# 305858   375.0     48.0  I eat quality foods but don't measure the amount|
# 308199   375.0     49.0  I eat quality foods but don't measure the amou...
# 311104   375.0     35.0  I eat quality foods but don't measure the amount|
# 324132   430.0     40.0  I eat quality foods but don't measure the amount|
# 329555   265.0     21.0  I eat quality foods but don't measure the amount|
# 330125   265.0     16.0  I eat quality foods but don't measure the amou...
# 340994   183.0     30.0  I eat quality foods but don't measure the amount|
# 348791   225.0     40.0  I eat quality foods but don't measure the amount|
# 352291   195.0     32.0  I eat quality foods but don't measure the amount|
# 355592   225.0     22.0  I eat quality foods but don't measure the amount|
# 362004   345.0     47.0  I eat strict Paleo|I eat quality foods but don...
# 372328   265.0     35.0  I eat quality foods but don't measure the amount|
# 375133     0.0     25.0  I eat quality foods but don't measure the amount|
# 380392   265.0     35.0  I eat quality foods but don't measure the amount|
# 382760   360.0     35.0                      I eat whatever is convenient|
# 421423   145.0      1.0                                 Decline to answer|
#
#                                                     train  \
# 34057   I workout mostly at a CrossFit Affiliate|I wor...
# 34127   I workout mostly at a CrossFit Affiliate|I hav...
# 34153   I workout mostly at a CrossFit Affiliate|I hav...
# 34154           I workout mostly at a CrossFit Affiliate|
# 34533           I workout mostly at a CrossFit Affiliate|
# 34651           I workout mostly at a CrossFit Affiliate|
# 34661           I workout mostly at a CrossFit Affiliate|
# 34720   I workout mostly at a CrossFit Affiliate|I rec...
# 34825   I workout mostly at a CrossFit Affiliate|I wor...
# 34838           I workout mostly at a CrossFit Affiliate|
# 34894   I workout mostly at a CrossFit Affiliate|I hav...
# 35036   I workout mostly at a CrossFit Affiliate|I inc...
# 35050   I workout mostly at a CrossFit Affiliate|I wri...
# 35073           I workout mostly at a CrossFit Affiliate|
# 35125   I workout mostly at a CrossFit Affiliate|I hav...
# 35132   I workout mostly at a CrossFit Affiliate|I wri...
# 35297           I workout mostly at a CrossFit Affiliate|
# 35299   I workout mostly at a CrossFit Affiliate|I hav...
# 35301   I workout mostly at a CrossFit Affiliate|I hav...
# 35372   I workout mostly at a CrossFit Affiliate|I hav...
# 35457   I workout mostly at a CrossFit Affiliate|I hav...
# 35466   I workout mostly at a CrossFit Affiliate|I hav...
# 35554   I workout mostly at a CrossFit Affiliate|I inc...
# 35556   I workout mostly at a CrossFit Affiliate|I hav...
# 35565   I workout mostly at a CrossFit Affiliate|I rec...
# 35622   I workout mostly at a CrossFit Affiliate|I hav...
# 35649           I workout mostly at a CrossFit Affiliate|
# 35682   I workout mostly at a CrossFit Affiliate|I hav...
# 35807   I workout mostly at a CrossFit Affiliate|I inc...
# 35839           I workout mostly at a CrossFit Affiliate|
# ...                                                   ...
# 223241  I workout mostly at a CrossFit Affiliate|I hav...
# 227249          I workout mostly at a CrossFit Affiliate|
# 227647          I workout mostly at a CrossFit Affiliate|
# 251087  I workout mostly at a CrossFit Affiliate|I rec...
# 262647          I workout mostly at a CrossFit Affiliate|
# 262860          I workout mostly at a CrossFit Affiliate|
# 264438  I workout mostly at a CrossFit Affiliate|I wri...
# 266392  I workout mostly at a CrossFit Affiliate|I wri...
# 275889  I workout mostly at a CrossFit Affiliate|I rec...
# 372328        I played youth or high school level sports|
# 375133  I played youth or high school level sports|I r...
# 380392  I played youth or high school level sports|I r...
# 382760    I have no athletic background besides CrossFit|
# 421423        I played youth or high school level sports|
#
#                                                experience  \
# 34057   I began CrossFit by trying it alone (without a...
# 34127   I began CrossFit by trying it alone (without a...
# 34153   I began CrossFit by trying it alone (without a...
# 34154   I began CrossFit with a coach (e.g. at an affi...
# 34533   I began CrossFit with a coach (e.g. at an affi...
# 34651   I began CrossFit by trying it alone (without a...
# 34661   I began CrossFit with a coach (e.g. at an affi...
# 34720   I began CrossFit by trying it alone (without a...
# 34825   I began CrossFit with a coach (e.g. at an affi...
# 34838   I began CrossFit with a coach (e.g. at an affi...
# 34894   I began CrossFit with a coach (e.g. at an affi...
# 35036   I began CrossFit by trying it alone (without a...
# 35050   I began CrossFit by trying it alone (without a...
# 35073   I began CrossFit with a coach (e.g. at an affi...
# 35125   I began CrossFit with a coach (e.g. at an affi...
# 35132   I began CrossFit by trying it alone (without a...
# 35297   I began CrossFit with a coach (e.g. at an affi...
# 35299   I began CrossFit with a coach (e.g. at an affi...
# 35301   I began CrossFit with a coach (e.g. at an affi...
# 35372   I began CrossFit with a coach (e.g. at an affi...
# 35457   I began CrossFit by trying it alone (without a...
# 35466   I began CrossFit by trying it alone (without a...
# 35554   I began CrossFit by trying it alone (without a...
# 35556   I began CrossFit by trying it alone (without a...
# 35565   I began CrossFit by trying it alone (without a...
# 35622   I began CrossFit with a coach (e.g. at an affi...
# 35649   I began CrossFit with a coach (e.g. at an affi...
# 35682   I began CrossFit with a coach (e.g. at an affi...
# 35807   I began CrossFit with a coach (e.g. at an affi...
# 35839   I began CrossFit with a coach (e.g. at an affi...
# ...                                                   ...
# 223241  I began CrossFit with a coach (e.g. at an affi...
# 227249  I began CrossFit with a coach (e.g. at an affi...
# 227647  I began CrossFit with a coach (e.g. at an affi...
# 251087  I began CrossFit with a coach (e.g. at an affi...
# 262647  I began CrossFit by trying it alone (without a...
# 262860  I began CrossFit with a coach (e.g. at an affi...
# 264438  I began CrossFit by trying it alone (without a...
# 266392  I began CrossFit by trying it alone (without a...
# 275889  I began CrossFit with a coach (e.g. at an affi...
# 276507  I began CrossFit with a coach (e.g. at an affi...
# 277864  I began CrossFit with a coach (e.g. at an affi...
# 280063  I began CrossFit with a coach (e.g. at an affi...
# 301042  I began CrossFit by trying it alone (without a...
# 302110  I began CrossFit with a coach (e.g. at an affi...
# 305858  I have had a life changing experience due to C...
# 308199  I began CrossFit with a coach (e.g. at an affi...
# 311104  I began CrossFit with a coach (e.g. at an affi...
# 324132  I began CrossFit with a coach (e.g. at an affi...
# 329555  I have completed the CrossFit Level 1 certific...
# 330125  I began CrossFit with a coach (e.g. at an affi...
# 340994  I began CrossFit with a coach (e.g. at an affi...
# 348791  I began CrossFit with a coach (e.g. at an affi...
# 352291  I began CrossFit with a coach (e.g. at an affi...
# 355592  I began CrossFit with a coach (e.g. at an affi...
# 362004  I began CrossFit with a coach (e.g. at an affi...
# 372328  I began CrossFit by trying it alone (without a...
# 375133  I began CrossFit by trying it alone (without a...
# 380392  I began CrossFit with a coach (e.g. at an affi...
# 382760  I began CrossFit by trying it alone (without a...
# 421423  I began CrossFit with a coach (e.g. at an affi...
#
#                                                  schedule  \
# 34057   I do multiple workouts in a day 3+ times a wee...
# 34127   I do multiple workouts in a day 3+ times a wee...
# 34153   I do multiple workouts in a day 3+ times a wee...
# 34154   I usually only do 1 workout a day|I do multipl...
# 34533          I do multiple workouts in a day 1x a week|
# 34651   I usually only do 1 workout a day|I typically ...
# 34661   I do multiple workouts in a day 3+ times a wee...
# 34720   I usually only do 1 workout a day|I typically ...
# 34825   I do multiple workouts in a day 3+ times a wee...
# 34838    I do multiple workouts in a day 3+ times a week|
# 34894   I do multiple workouts in a day 3+ times a wee...
# 35036   I usually only do 1 workout a day|I do multipl...
# 35050   I do multiple workouts in a day 3+ times a wee...
# 35073                  I usually only do 1 workout a day|
# 35125   I do multiple workouts in a day 2x a week|I st...
# 35132   I do multiple workouts in a day 3+ times a wee...
# 35297                  I usually only do 1 workout a day|
# 35299   I do multiple workouts in a day 3+ times a wee...
# 35301                  I usually only do 1 workout a day|
# 35372    I do multiple workouts in a day 3+ times a week|
# 35457   I do multiple workouts in a day 3+ times a wee...
# 35466                  I usually only do 1 workout a day|
# 35554   I usually only do 1 workout a day|I strictly s...
# 35556   I do multiple workouts in a day 1x a week|I ty...
# 35565   I do multiple workouts in a day 2x a week|I do...
# 35622   I usually only do 1 workout a day|I typically ...
# 35649   I usually only do 1 workout a day|I strictly s...
# 35682   I do multiple workouts in a day 3+ times a wee...
# 35807   I do multiple workouts in a day 2x a week|I do...
# 35839          I do multiple workouts in a day 2x a week|
# ...                                                   ...
# 223241  I do multiple workouts in a day 3+ times a wee...
# 227249                 I usually only do 1 workout a day|
# 227647                 I usually only do 1 workout a day|
# 251087  I usually only do 1 workout a day|I typically ...
# 262647  I usually only do 1 workout a day|I strictly s...
# 262860  I do multiple workouts in a day 3+ times a wee...
# 264438  I usually only do 1 workout a day|I typically ...
# 266392  I do multiple workouts in a day 3+ times a wee...
# 275889  I usually only do 1 workout a day|I do multipl...
# 276507  I usually only do 1 workout a day|I typically ...
# 277864  I usually only do 1 workout a day|I do multipl...
# 280063  I do multiple workouts in a day 3+ times a wee...
# 301042  I usually only do 1 workout a day|I strictly s...
# 302110   I do multiple workouts in a day 3+ times a week|
# 305858                 I usually only do 1 workout a day|
# 308199  I usually only do 1 workout a day|I strictly s...
# 311104  I usually only do 1 workout a day|I do multipl...
# 324132  I do multiple workouts in a day 3+ times a wee...
# 329555  I strictly schedule my rest days|I typically r...
# 330125  I usually only do 1 workout a day|I strictly s...
# 340994                 I usually only do 1 workout a day|
# 348791  I do multiple workouts in a day 2x a week|I st...
# 352291         I do multiple workouts in a day 1x a week|
# 355592  I usually only do 1 workout a day|I typically ...
# 362004  I do multiple workouts in a day 2x a week|I st...
# 372328      I typically rest fewer than 4 days per month|
# 375133  I do multiple workouts in a day 3+ times a wee...
# 380392  I do multiple workouts in a day 2x a week|I st...
# 382760  I usually only do 1 workout a day|I typically ...
# 421423                 I usually only do 1 workout a day|
#
#                      howlong   retrieved_datetime
# 34057           6-12 months|  2015-03-01 22:51:30
# 34127             2-4 years|  2015-03-01 22:54:58
# 2          NaN
# 3         67.0
# 4         65.0
# 5         73.0
# 6         72.0
# 7          NaN
# 8         72.0
# 9         68.0
# 10        69.0
# 11         NaN
# 12        65.0
# 13        71.0
# 14         NaN
# 15        72.0
# 16        66.0
# 17        74.0
# 18        70.0
# 19         NaN
# 20        72.0
# 21        71.0
# 22        70.0
# 23        70.0
# 24         NaN
# 25        66.0
# 26         NaN
# 27        68.0
# 28         NaN
# 29         NaN
#           ...
# 422976     NaN
# 422977     NaN
# 422978     NaN
# 422979     NaN
# 422980     NaN
# 422981    60.0
# 422982    62.0
# 422983     NaN
# 422984     NaN
# 422985     NaN
# 422986     NaN
# 422987     NaN
# 422988    65.0
# 422989     NaN
# 422990     NaN
# 422991     NaN
# 422992     NaN
# 422993     NaN
# 422994     NaN
# 422995     NaN
# 422996     NaN
# 422997    65.0
# 422998     NaN
# 422999     NaN
# 423000     NaN
# 423001     NaN
# 423002     NaN
# 423003     NaN
# 423004    64.0
# 423005     NaN
# Name: height, Length: 423006, dtype: float64

# %% [markdown]
# Visualize the data:

# %% [markdown]
# Data frame with variables for model.

# %%
data_model_1 = data.filter(['height'], axis=1)

# %%
data_model_1.head()
# Out:
#    height
# 0    70.0
# 1    70.0
# 2     NaN
# 3    67.0
# 4    65.0

# %%
data_model_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 423006 entries, 0 to 423005
# Data columns (total 1 columns):
# height    159869 non-null float64
# dtypes: float64(1)
# memory usage: 3.2 MB

# %%
pd.DataFrame.hist(data_model_1, figsize = [7,7]);

# %% [markdown]
# According to the histogram, the overall sum of the height is 160000.

# %% [markdown]
# # Question 3

# %% [markdown]
# What is the average height?

# %%
data["height"].mean()
# Out:
# 120.6216840037781

# %% [markdown]
# # Question 4

# %% [markdown]
# Use simple random sampling to sample from the dataset. Choose a sample of 20000.

# %%
import numpy as np
plt.rc("font", size=14)

# %% [markdown]
# #### Simple random sampling, with 20000 samples.

# %%
data1 = pd.Series(np.random.randn(20000))

# %%
data1.head()
# Out:
# 0    0.931503
# 1   -1.265463
# 2    0.002532
# 3   -0.191227
# 4   -0.061341
# dtype: float64

# %%
data1 = pd.DataFrame(np.random.randn(50, 2), columns=list('AB'))

# %%
data1.head()
# Out:
#           A         B
# 0  0.189984 -0.255010
# 1  0.319485 -1.894660
# 2 -0.960558  1.142811
# 3  1.938644 -0.523258
# 4  0.112410  1.520850

# %% [markdown]
# # Question 5

# %% [markdown]
# Compare simple random sampling and stratified random sampling. Compare the means generated by the two sampling techniques and discuss your observations below your code.

# %%
data2= pd.DataFrame(dict(
        A=[1, 1, 1, 2, 2, 2, 2, 3, 4, 4],
        B=range(10)))

# %%
data2.groupby('A', group_keys=False).apply(lambda x: x.sample(min(len(x), 2)))
# Out:
#    A  B
# 0  1  0
# 1  1  1
# 4  2  4
# 5  2  5
# 7  3  7
# 8  4  8
# 9  4  9

# %% [markdown]
# #### Simple random sampling mean:

# %%
data1.mean()
# Out:
# A   -0.051931
# B   -0.130765
# dtype: float64

# %% [markdown]
# For Simple random sampling, the mean at A is greater than the mean at B.

# %% [markdown]
# #### Stratified random sampling mean:

# %%
data2.mean()
# Out:
# A    2.2
# B    4.5
# dtype: float64

# %% [markdown]
# For Stratified random sampling, the mean at B is greater than the mean at A.

# %% [markdown]
# # Question 6

# %% [markdown]
# In this question we are going to implement cluster sampling. Data is divided into clusters, if it isn't already divided into clusters, and then we use simple random sampling to select a number of clusters from the sample. From the group of selected clusters, we again use simple random sampling to select random data points. These now form our sample.
#
# Let's implement this procedure using some randomly generated data that we are going to group into clusters.

# %%
#n_clusters = 10
#data = stats.norm.rvs(loc=0,        # mean 0
 #                     scale=1,      # variance 1
  #                    size=100000,  # number of points
   #                   random_state=None)

#data = pd.DataFrame({'var1': data})  # turn list into dataframe with heading var1
#
#cluster = [rnd.randint(0,9) for c in range(100000)] # generate cluster numbers for grouping
#
#n_col = pd.Series(cluster) # turn list into Series object
#data['cluster'] = n_col.values
#data.head()

# %% [markdown]
# Now that we've generated random data and placed the data into clusters, generate a sample from the *athletes* data using cluster sampling technique.

# %%
n_clusters = 10

cluster = [rnd.randint(0,9) for c in range(423006)] # generate cluster numbers for grouping

n_col = pd.Series(cluster) # turn list into Series object
data['cluster'] = n_col.values
data.head()
# Out:
#    athlete_id           name               region          team  \
# 0      2554.0      Pj Ablang           South West   Double Edge
# 1      3517.0  Derek Abdella                  NaN           NaN
# 2      4691.0            NaN                  NaN           NaN
# 3      5164.0    Abo Brandon  Southern California  LAX CrossFit
# 4      5286.0    Bryce Abbey                  NaN           NaN
#
#               affiliate gender   age  height  weight   fran   ...     backsq  \
# 0  Double Edge CrossFit   Male  24.0    70.0   166.0    NaN   ...      305.0
# 1                   NaN   Male  42.0    70.0   190.0    NaN   ...        NaN
# 2                   NaN    NaN   NaN     NaN     NaN    NaN   ...        NaN
# 3          LAX CrossFit   Male  40.0    67.0     NaN  211.0   ...      325.0
# 4                   NaN   Male  32.0    65.0   149.0  206.0   ...      325.0
#
#    pullups                                                eat  \
# 0      NaN                                                NaN
# 1      NaN                                                NaN
# 2      NaN                                                NaN
# 3     25.0               I eat 1-3 full cheat meals per week|
# 4     50.0  I eat quality foods but don't measure the amount|
#
#                                                train  \
# 0  I workout mostly at a CrossFit Affiliate|I hav...
# 1  I have a coach who determines my programming|I...
# 2                                                NaN
# 3  I workout mostly at a CrossFit Affiliate|I hav...
# 4  I workout mostly at a CrossFit Affiliate|I inc...
#
#                                           background  \
# 0  I played youth or high school level sports|I r...
# 1        I played youth or high school level sports|
# 2                                                NaN
# 3        I played youth or high school level sports|
# 4                           I played college sports|
#
#                                           experience  \
# 0  I began CrossFit with a coach (e.g. at an affi...
# 1  I began CrossFit with a coach (e.g. at an affi...
# 2                                                NaN
# 3  I began CrossFit by trying it alone (without a...
# 4  I began CrossFit by trying it alone (without a...
#
#                                             schedule     howlong  \
# 0         I do multiple workouts in a day 2x a week|   4+ years|
# 1         I do multiple workouts in a day 2x a week|   4+ years|
# 2                                                NaN         NaN
# 3                 I usually only do 1 workout a day|   4+ years|
# 4  I usually only do 1 workout a day|I strictly s...  1-2 years|
#
#    retrieved_datetime  cluster
# 0                 NaN        9
# 1                 NaN        0
# 2                 NaN        9
# 3                 NaN        4
# 4                 NaN        4
#
# [5 rows x 29 columns]

# %%
data.shape
# Out:
# (423006, 29)
